# %% [markdown]
# Let's start by reading the data files.

# %%
import numpy as np
import time

# %%
def reader(file_path):
    with open(file_path, 'r') as file:
        data = file.readlines() 
    # number of potential warehouse locations (m), number of customers (n) assigned
    m, n = map(int, data[0].strip().split(" "))

    capacity, cost = map(int, data[1].rstrip('.').split())

    return print(data[1])

# %%
path = "data/beasley-cap/70/cap71.txt"

with open(path, 'r') as file:
    data = file.readlines() 
# number of potential warehouse locations (m), number of customers (n) assigned
m, n = map(int, data[0].strip().split(" "))

warehouse_data = []
for i in range(1, m + 1):
    capacity, cost = map(float, data[i].strip().split(" "))
    warehouse_data.append([capacity, cost])
    print(warehouse_data)
# Out:
# [[58268.0, 7500.0]]
# [[58268.0, 7500.0], [58268.0, 7500.0]]
# [[58268.0, 7500.0], [58268.0, 7500.0], [58268.0, 7500.0]]
# [[58268.0, 7500.0], [58268.0, 7500.0], [58268.0, 7500.0], [58268.0, 7500.0]]
# [[58268.0, 7500.0], [58268.0, 7500.0], [58268.0, 7500.0], [58268.0, 7500.0], [58268.0, 7500.0]]
# [[58268.0, 7500.0], [58268.0, 7500.0], [58268.0, 7500.0], [58268.0, 7500.0], [58268.0, 7500.0], [58268.0, 7500.0]]
# [[58268.0, 7500.0], [58268.0, 7500.0], [58268.0, 7500.0], [58268.0, 7500.0], [58268.0, 7500.0], [58268.0, 7500.0], [58268.0, 7500.0]]
# [[58268.0, 7500.0], [58268.0, 7500.0], [58268.0, 7500.0], [58268.0, 7500.0], [58268.0, 7500.0], [58268.0, 7500.0], [58268.0, 7500.0], [58268.0, 7500.0]]
# [[58268.0, 7500.0], [58268.0, 7500.0], [58268.0, 7500.0], [58268.0, 7500.0], [58268.0, 7500.0], [58268.0, 7500.0], [58268.0, 7500.0], [58268.0, 7500.0], [58268.0, 7500.0]]
# ...
